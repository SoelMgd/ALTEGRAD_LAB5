# %%
# !pip install -r /content/ALTEGRAD_LAB5/code/lab4-requirements.txt

# %% [markdown]
# ## Node Embeddings with DeepWalk

# %%
# %time

# !python /content/ALTEGRAD_LAB5/code/part1/visualization.py
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.48 µs
# Number of nodes: 33226
# Number of edges: 354529
# Generating walks
# Training word2vec
# Node embeddings generated successfully!
# Figure(2000x1500)

# %% [markdown]
# ## Node Classification

# %%
# %%time

# !python /content/ALTEGRAD_LAB5/code/part1/node_classification.py
# Out:
# Number of nodes: 34
# Number of edges: 78
# Figure(800x800)
# Generating walks
# Training word2vec
# Classification accuracy with DeepWalk embeddings: 1.00
# Classification accuracy with spectral embeddings: 0.86
# CPU times: user 28.7 ms, sys: 7.18 ms, total: 35.9 ms
# Wall time: 4.32 s

# %%
from IPython.display import Image, display

display(Image(filename='/content/KarateNetwork.png'))

# %% [markdown]
# ## GNN classification

# %%
# %%time
# Task 11
# !python /content/ALTEGRAD_LAB5/code/part2/gnn_karate.py
# Out:
# 34
# 78
# /content/ALTEGRAD_LAB5/code/part2/utils.py:51: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:651.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# Epoch: 001 loss_train: 0.6949 acc_train: 0.5556 time: 1.0133s
# Epoch: 002 loss_train: 0.6838 acc_train: 0.5556 time: 0.0196s
# Epoch: 003 loss_train: 0.6796 acc_train: 0.5556 time: 0.0096s
# Epoch: 004 loss_train: 0.6782 acc_train: 0.5556 time: 0.0128s
# Epoch: 005 loss_train: 0.6755 acc_train: 0.5556 time: 0.0151s
# Epoch: 006 loss_train: 0.6709 acc_train: 0.5556 time: 0.0178s
# Epoch: 007 loss_train: 0.6557 acc_train: 0.5926 time: 0.0050s
# Epoch: 008 loss_train: 0.6426 acc_train: 0.6296 time: 0.0139s
# Epoch: 009 loss_train: 0.6387 acc_train: 0.5926 time: 0.0130s
# Epoch: 010 loss_train: 0.6303 acc_train: 0.7037 time: 0.0132s
# ...

# %%
# %%time
# Task 12
# with features = np.ones((n, 1))
# !python /content/ALTEGRAD_LAB5/code/part2/gnn_karate.py
# Out:
# 34
# 78
# /content/ALTEGRAD_LAB5/code/part2/utils.py:51: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:651.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# Epoch: 001 loss_train: 0.7127 acc_train: 0.3704 time: 1.2701s
# Epoch: 002 loss_train: 0.7077 acc_train: 0.3333 time: 0.0058s
# Epoch: 003 loss_train: 0.6872 acc_train: 0.5926 time: 0.0048s
# Epoch: 004 loss_train: 0.6970 acc_train: 0.4815 time: 0.0054s
# Epoch: 005 loss_train: 0.6921 acc_train: 0.5185 time: 0.0045s
# Epoch: 006 loss_train: 0.6858 acc_train: 0.5185 time: 0.0054s
# Epoch: 007 loss_train: 0.6721 acc_train: 0.6296 time: 0.0046s
# Epoch: 008 loss_train: 0.7073 acc_train: 0.5556 time: 0.0047s
# Epoch: 009 loss_train: 0.6973 acc_train: 0.5556 time: 0.0046s
# Epoch: 010 loss_train: 0.6986 acc_train: 0.5556 time: 0.0045s
# ...

# %%
# %%time
# Task 13
# !python /content/ALTEGRAD_LAB5/code/part2/gnn_cora.py
# Out:
# Dataset has 2708 nodes, 5429 edges, 1433 features.
# /content/ALTEGRAD_LAB5/code/part2/utils.py:51: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:651.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# Epoch: 001 loss_train: 1.9137 acc_train: 0.1860 loss_val: 1.8957 acc_val: 0.3044 time: 0.8339s
# Epoch: 002 loss_train: 1.9033 acc_train: 0.2802 loss_val: 1.8863 acc_val: 0.3044 time: 0.0076s
# Epoch: 003 loss_train: 1.8947 acc_train: 0.2999 loss_val: 1.8765 acc_val: 0.3044 time: 0.0071s
# Epoch: 004 loss_train: 1.8850 acc_train: 0.3005 loss_val: 1.8660 acc_val: 0.3044 time: 0.0072s
# Epoch: 005 loss_train: 1.8733 acc_train: 0.3005 loss_val: 1.8541 acc_val: 0.3044 time: 0.0069s
# Epoch: 006 loss_train: 1.8659 acc_train: 0.3005 loss_val: 1.8410 acc_val: 0.3044 time: 0.0068s
# ...

# %%
display(Image(filename='/content/Cora.png'))
